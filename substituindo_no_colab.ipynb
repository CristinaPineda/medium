# %% [markdown]
# **SUBSTITUINDO INFORMAÇÕES NO COLAB**
#
# Que a gente sabe que o Google Colab é uma ferramenta poderosa para o desenvolvimento de código Python a gente sabe.
#
# Não sabe como funciona o Google Colab ainda?
# Dá uma olhada aqui : https://colab.research.google.com/notebooks/intro.ipynb#scrollTo=GJBs_flRovLc
#
# Vamos falar sobre editar códigos no Colab.
#
# O Google Colab possui uma ferramenta ótima para substituição de caracteres.
#
# Escreveu aquele montão de linhas de código ou recebeu aquele notebook enorme e vai precisar mudar alguma coisa, trocar o nome de alguma variavel? É só usar o ícone da lupa que está logo abaixo do menu sanduíche do Colab:

# %% [markdown]
# ![imagem_1.png](data:image/png;base64,...)

# %% [markdown]
# Insira o que deseja encontrar e pelo que deseja substituir e veja todas as mudanças que podem ser feitas!

# %% [markdown]
# ![imagem_2.png](data:image/png;base64,...)

# %% [markdown]
# O recurso de localizar passa por todas as células, sejam elas de texto ou código.
#
# *Fácil e rápido*.
#
# Conhecia essa?
#
# Comente e dê sugestões!!
#
# Até breve!!
